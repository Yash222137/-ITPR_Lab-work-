# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/-ITPR_Lab-work-/blob/main/CLASSS_WORK/Numpy/ones_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create a ones array
import numpy as np
numbers = np.ones((4,3) )
print(numbers)
